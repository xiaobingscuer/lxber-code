# %% [markdown]
# # 洛书的三维表达

# %% [markdown]
# > 参见头条霹雳火的专栏

# %% [markdown]
# > 洛书的8个方向边的三个数之和为15，如果这个三个数分别为x,y,z，那么用三维直角坐标系画出来是什么样子的？

# %%
from mpl_toolkits.mplot3d import Axes3D

import numpy as np
import matplotlib.pyplot as plt
import matplotlib

plt.rcParams['legend.fontsize'] = 10

fig = plt.figure()
ax = fig.gca(projection='3d')
# ax = plt.subplot(111,projection='3d')

# Prepare arrays x, y, z
x = [4, 3, 8, 4, 9, 2, 4, 2]
y = [9, 5, 1, 3, 5, 7, 5, 5]
z = [2, 7, 6, 8, 1, 6, 6, 8]

for ex, ey, ez, c, m, la in [(x[i], y[i], z[i], 'r', 'o', i) for i in range(8)]:
    ax.scatter(ex, ey, ez, c=c, marker=m)
    ax.text(ex, ey, ez, la+1, color='red')
    
for i in range(8):
    for j in range(i, 8):
        ax.plot([x[i], x[j]], [y[i], y[j]], [z[i], z[j]], label='luoshu 3d', color='black')
        
# ax.legend()
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')

# plt.show()

# ax.view_init(elev=20., azim=30)

plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D

import numpy as np
import matplotlib.pyplot as plt
import matplotlib

plt.rcParams['legend.fontsize'] = 10

fig = plt.figure()
ax = fig.gca(projection='3d')
# ax = plt.subplot(111,projection='3d')

# Prepare arrays x, y, z
x = [4, 3, 8, 4, 9, 2, 4, 2]
y = [9, 5, 1, 3, 5, 7, 5, 5]
z = [2, 7, 6, 8, 1, 6, 6, 8]

for ex, ey, ez, c, m, la in [(x[i], y[i], z[i], 'r', 'o', i) for i in range(8)]:
    ax.scatter(ex, ey, ez, c=c, marker=m)
    ax.text(ex, ey, ez, la, color='red')
    
for i in range(8):
    for j in range(i, 8):
        ax.plot([x[i], x[j]], [y[i], y[j]], [z[i], z[j]], label='luoshu 3d', color='black')
        
# ax.legend()
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')

# plt.show()

ax.view_init(elev=20., azim=30)
# ax.view_init(elev=20., azim=-40)

plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D

import numpy as np
import matplotlib.pyplot as plt
import matplotlib

plt.rcParams['legend.fontsize'] = 10

fig = plt.figure()
ax = fig.gca(projection='3d')
# ax = plt.subplot(111,projection='3d')

# Prepare arrays x, y, z
x = [0, 4, 3, 8, 4, 9, 2, 4, 2]
y = [0, 9, 5, 1, 3, 5, 7, 5, 5]
z = [0, 2, 7, 6, 8, 1, 6, 6, 8]

for ex, ey, ez, c, m, la in [(x[i], y[i], z[i], 'r', 'o', i) for i in range(9)]:
    ax.scatter(ex, ey, ez, c=c, marker=m)
    ax.text(ex, ey, ez, la, color='red')
    
for i in range(9):
    for j in range(i, 9):
        ax.plot([x[i], x[j]], [y[i], y[j]], [z[i], z[j]], label='luoshu 3d', color='black')
        
# ax.legend()
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')

# plt.show()

ax.view_init(elev=20., azim=-40)

plt.show()

# %%
point = [[4,9,2],[3,5,7],[8,1,6],[4,3,8],[9,5,1],[2,7,6],[4,5,6],[2,5,8]]
point_v2 = []
point_v3 = []

sum = []
sum_v2 = []
sum_v3 = []

for i in range(len(point)):
    point_v2.append([0, 0, 0])
    point_v3.append([0, 0, 0])
    s = 0
    s_v2 = 0
    s_v3 = 0
    for j in range(3):
        point_v2[i][j] = point[i][j] * 10 + point[i][(j + 1) % 3]
        point_v3[i][j] = point[i][j] * 100 + point[i][(j + 1) % 3] * 10 + point[i][(j + 2) % 3]
        s += point[i][j]
        s_v2 += point_v2[i][j]
        s_v3 += point_v3[i][j]
    sum.append(s)
    sum_v2.append(s_v2)
    sum_v3.append(s_v3)

print(point)
print(point_v2)
print(point_v3)

print(sum)
print(sum_v2)
print(sum_v3)

print(sum[0]/15)
print(sum_v2[0]/15)
print(sum_v3[0]/15)

# point = [[4, 9, 2], [3, 5, 7], [8, 1, 6], [4, 3, 8], [9, 5, 1], [2, 7, 6], [4, 5, 6], [2, 5, 8]]
# point_v2 = [[49, 92, 24], [35, 57, 73], [81, 16, 68], [43, 38, 84], [95, 51, 19], [27, 76, 62], [45, 56, 64], [25, 58, 82]]
# point_v3 = [[492, 924, 249], [357, 573, 735], [816, 168, 681], [438, 384, 843], [951, 519, 195], [276, 762, 627], [456, 564, 645], [258, 582, 825]]
# sum = [15, 15, 15, 15, 15, 15, 15, 15]
# sum_v2 = [165, 165, 165, 165, 165, 165, 165, 165]
# sum_v3 = [1665, 1665, 1665, 1665, 1665, 1665, 1665, 1665]
# sum[0]/15 = 1.0
# sum_v2[0]/15 = 11.0
# sum_v3[0]/15 = 111.0
# Out:
# [[4, 9, 2], [3, 5, 7], [8, 1, 6], [4, 3, 8], [9, 5, 1], [2, 7, 6], [4, 5, 6], [2, 5, 8]]
# [[49, 92, 24], [35, 57, 73], [81, 16, 68], [43, 38, 84], [95, 51, 19], [27, 76, 62], [45, 56, 64], [25, 58, 82]]
# [[492, 924, 249], [357, 573, 735], [816, 168, 681], [438, 384, 843], [951, 519, 195], [276, 762, 627], [456, 564, 645], [258, 582, 825]]
# [15, 15, 15, 15, 15, 15, 15, 15]
# [165, 165, 165, 165, 165, 165, 165, 165]
# [1665, 1665, 1665, 1665, 1665, 1665, 1665, 1665]
# 1.0
# 11.0
# 111.0

# %%
import math
import numpy as np

def nonlinear(k, sign = 'sin'):
    if sign == 'sin':
        return math.sin(k)
    elif sign == 'cos':
        return math.cos(k)
    else:
        return math.tan(k)

point = [[4,9,2],[3,5,7],[8,1,6],[4,3,8],[9,5,1],[2,7,6],[4,5,6],[2,5,8]]
points = []
sums = []
maxk = 2*math.pi
num = 10.0
print(maxk/num)
#ks = [k for k in range(maxk)]
ks = [k for k in np.arange(0, maxk, maxk/num)]
print(ks)

for k in ks:
    t = []
    ss = []
    for p in point:
        tt = [0, 0, 0]
        s = 0
        for j in range(3):
            tt[j] = p[j] * k + p[(j + 1) % 3]
#             tt[j] = p[j] * nonlinear(k,'sin') + p[(j + 1) % 3] * nonlinear(k,'cos') + p[(j + 2) % 3]*nonlinear(k,'tan')
            s += tt[j]
        t.append(tt)
        ss.append(s)
    points.append(t)
    sums.append(ss)

for ki in range(len(ks)):
    print(points[ki])
    print(sums[ki])
    print(sums[ki][0]/15)

from mpl_toolkits.mplot3d import Axes3D

import numpy as np
import matplotlib.pyplot as plt
import matplotlib

plt.rcParams['legend.fontsize'] = 10

fig = plt.figure()
ax = fig.gca(projection='3d')

for point in points:
    for ex, ey, ez, c, m, la in [(point[i][0], point[i][1], point[i][2], 'r', 'o', i) for i in range(8)]:
        ax.scatter(ex, ey, ez, c=c, marker=m, s=1)
        ax.text(ex, ey, ez, la, color='red')

    for i in range(8):
        for j in range(i, 8):
            ax.plot([point[i][0], point[j][0]], [point[i][1], point[j][1]], [point[i][2], point[j][2]], label='luoshu 3d', linewidth=1.0, color='black')

ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')

ax.view_init(elev=20., azim=-40)

plt.show()
# Out:
# 0.6283185307179586
# [0.0, 0.6283185307179586, 1.2566370614359172, 1.8849555921538759, 2.5132741228718345, 3.141592653589793, 3.7699111843077517, 4.39822971502571, 5.026548245743669, 5.654866776461628]
# [[9.0, 2.0, 4.0], [5.0, 7.0, 3.0], [1.0, 6.0, 8.0], [3.0, 8.0, 4.0], [5.0, 1.0, 9.0], [7.0, 6.0, 2.0], [5.0, 6.0, 4.0], [5.0, 8.0, 2.0]]
# [15.0, 15.0, 15.0, 15.0, 15.0, 15.0, 15.0, 15.0]
# 1.0
# [[11.513274122871834, 7.654866776461628, 5.256637061435917], [6.884955592153876, 10.141592653589793, 7.39822971502571], [6.026548245743669, 6.628318530717959, 11.769911184307752], [5.5132741228718345, 9.884955592153876, 9.026548245743669], [10.654866776461628, 4.141592653589793, 9.628318530717959], [8.256637061435917, 10.39822971502571, 5.769911184307752], [7.5132741228718345, 9.141592653589793, 7.769911184307752], [6.256637061435917, 11.141592653589793, 7.026548245743669]]
# ...

# %%
point = [[4, 9, 2], [3, 5, 7], [8, 1, 6], [4, 3, 8], [9, 5, 1], [2, 7, 6], [4, 5, 6], [2, 5, 8]]
point_v2 = [[49, 92, 24], [35, 57, 73], [81, 16, 68], [43, 38, 84], [95, 51, 19], [27, 76, 62], [45, 56, 64], [25, 58, 82]]
point_v3 = [[492, 924, 249], [357, 573, 735], [816, 168, 681], [438, 384, 843], [951, 519, 195], [276, 762, 627], [456, 564, 645], [258, 582, 825]]


from mpl_toolkits.mplot3d import Axes3D

import numpy as np
import matplotlib.pyplot as plt
import matplotlib

plt.rcParams['legend.fontsize'] = 10

fig = plt.figure()
ax = fig.gca(projection='3d')
# ax = plt.subplot(111,projection='3d')

# Prepare arrays x, y, z
# x = [0, 4, 3, 8, 4, 9, 2, 4, 2]
# y = [0, 9, 5, 1, 3, 5, 7, 5, 5]
# z = [0, 2, 7, 6, 8, 1, 6, 6, 8]

for ex, ey, ez, c, m, la in [(point[i][0], point[i][1], point[i][2], 'r', 'o', i) for i in range(8)]:
    ax.scatter(ex, ey, ez, c=c, marker=m)
    ax.text(ex, ey, ez, la, color='red')

for ex, ey, ez, c, m, la in [(point_v2[i][0], point_v2[i][1], point_v2[i][2], 'r', 'o', i) for i in range(8)]:
    ax.scatter(ex, ey, ez, c=c, marker=m)
    ax.text(ex, ey, ez, la, color='red')
    
# for ex, ey, ez, c, m, la in [(point_v3[i][0], point_v3[i][1], point_v3[i][2], 'r', 'o', i) for i in range(8)]:
#     ax.scatter(ex, ey, ez, c=c, marker=m)
#     ax.text(ex, ey, ez, la, color='red')
    
for i in range(8):
    for j in range(i, 8):
        ax.plot([point[i][0], point[j][0]], [point[i][1], point[j][1]], [point[i][2], point[j][2]], label='luoshu 3d', color='black')

for i in range(8):
    for j in range(i, 8):
        ax.plot([point_v2[i][0], point_v2[j][0]], [point_v2[i][1], point_v2[j][1]], [point_v2[i][2], point_v2[j][2]], label='luoshu 3d', color='black')

# for i in range(8):
#     for j in range(i, 8):
#         ax.plot([point_v3[i][0], point_v3[j][0]], [point_v3[i][1], point_v3[j][1]], [point_v3[i][2], point_v3[j][2]], label='luoshu 3d', color='black')



        
# ax.legend()
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')

# plt.show()

ax.view_init(elev=20., azim=10)

plt.show()

# %%
import time
import threading as td
import multiprocessing as mp

# %%
def normal():
    res = 0
    for _ in range(2):
        for i in range(1000000):
            res += i + i**2 + i**3
    print('normal:', res)

start = time.time()

normal()

end = time.time()
print('time cost: %s s' % float(end-start))
# Out:
# normal: 499999666667166666000000
# time cost: 4.042462110519409 s

# %%
def job(q):
    res = 0
    for i in range(1000000):
        res += i + i**2 + i**3
    q.put(res)

# %%
def multithread():
    q = mp.Queue() 
    t1 = td.Thread(target=job, args=(q,))
    t2 = td.Thread(target=job, args=(q,))
    t1.start()
    t2.start()
    t1.join()
    t2.join()
    res1 = q.get()
    res2 = q.get()
    print('multithread:', res1 + res2)
    
start = time.time()

multithread()

end = time.time()
print('time cost: %s s' % float(end-start))
# Out:
# multithread: 499999666667166666000000
# time cost: 3.910043716430664 s

# %%
def multicore():
    q = mp.Queue()
    p1 = mp.Process(target=job, args=(q,))
    p2 = mp.Process(target=job, args=(q,))
    p1.start()
    p2.start()
    p1.join()
    p2.join()
    res1 = q.get()
    res2 = q.get()
    print('multicore:',res1 + res2)
    
start = time.time()

multicore()

end = time.time()
print('time cost: %s s' % float(end-start))

# %%
import time
def sayhello(str):
    print ("Hello ",str)
    time.sleep(2)

name_list =['xiaozi','aa','bb','cc']
start_time = time.time()
for i in range(len(name_list)):
    sayhello(name_list[i])
print ('%d second'% (time.time()-start_time))
# Out:
# Hello  xiaozi
# Hello  aa
# Hello  bb
# Hello  cc
# 8 second

# %%
import time
import threadpool  
def sayhello(str):
    print ("Hello ",str)
    time.sleep(2)

name_list =['xiaozi','aa','bb','cc']
start_time = time.time()
pool = threadpool.ThreadPool(4) 
requests = threadpool.makeRequests(sayhello, name_list) 
[pool.putRequest(req) for req in requests] 
pool.wait() 
print ('%d second'% (time.time()-start_time))
# Out:
# Hello  xiaozi
# Hello Hello  aa
#  bb
# Hello  cc
# 2 second

# %%
import threading

def func():
    a, b = 0, 1
    r, i , n = 0, 0, 0
    while True:
        itrs = n - i
        for _ in range(itrs):
            r = a + b
            b, a = a, r
            i += 1
        n = yield r
        
        

f = func()
f.send(None)

for i in range(0, 10, 2):
    print('=============== i = %d ======' % i)
    print (f.send(i))
# Out:
# =============== i = 0 ======
# 0
# =============== i = 2 ======
# 1
# =============== i = 4 ======
# 3
# =============== i = 6 ======
# 8
# =============== i = 8 ======
# 21

# %%
clsqabclxb  123456
